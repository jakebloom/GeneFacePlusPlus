# %% [markdown]
# Check GPU

# %%
# !nvidia-smi --query-gpu=name,memory.total,memory.free --format=csv,noheader
# Out:
# Tesla T4, 15360 MiB, 15101 MiB

# %%
# !nvcc --version

import torch
print(torch.__version__)
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0
# 2.2.1+cu121

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Installation

# %%
import sys
import torch
pyt_version_str=torch.__version__.split("+")[0].replace(".", "")
version_str="".join([
    f"py3{sys.version_info.minor}_cu",
    torch.version.cuda.replace(".",""),
    f"_pyt{pyt_version_str}"
])
# !pip install fvcore iopath
# !pip install --no-index --no-cache-dir pytorch3d -f https://dl.fbaipublicfiles.com/pytorch3d/packaging/wheels/{version_str}/download.html

# %%
# install dependencies, about 5~10 min
# !pip install tensorboard==2.13.0 tensorboardX==2.6.1
# !pip install pyspy==0.1.1
# !pip install protobuf==3.20.3
# !pip install scipy==1.9.1
# !pip install kornia==0.5.0
# !pip install trimesh==3.22.0
# !pip install einops==0.6.1 torchshow==0.5.1
# !pip install imageio==2.31.1 imageio-ffmpeg==0.4.8
# !pip install scikit-learn==1.3.0 scikit-image==0.21.0
# !pip install av==10.0.0 lpips==0.1.4
# !pip install timm==0.9.2 librosa==0.9.2

# %%
# !pip install mmcv==2.1.0 -f https://download.openmmlab.com/mmcv/dist/cu121/torch2.1/index.html

# %%
# !pip install transformers==4.33.2
# !pip install pretrainedmodels==0.7.4
# !pip install ninja==1.11.1
# !pip install faiss-cpu==1.7.4
# !pip install praat-parselmouth==0.4.3 moviepy==1.0.3
# !pip install mediapipe==0.10.7
# !pip install --upgrade attr
# !pip install beartype==0.16.4 gateloop_transformer==0.4.0
# !pip install torchode==0.2.0 torchdiffeq==0.2.3
# !pip install hydra-core==1.3.2 pandas==2.1.3
# !pip install pytorch_lightning==2.1.2
# !pip install httpx==0.23.3
# !pip install gradio==4.16.0
# !pip install gdown
# !pip install pyloudnorm webrtcvad pyworld==0.2.1rc0 pypinyin==0.42.0
# !pip install PyMCubes
# !pip install pyyaml
# !pip install setproctitle

# %% [markdown]
# Clone code and download checkpoints

# %%
# clone GeneFacePlusPlus repo from github
# !git clone https://github.com/yerfor/GeneFacePlusPlus
# %cd GeneFacePlusPlus

# %%
# replacing all 'c++14' with 'c++17' for compatible in CUDA 12
# special thanks to @yyheart in https://github.com/yerfor/GeneFacePlusPlus/issues/12
import glob
all_files = glob.glob("modules/radnerfs/*.py") + glob.glob("modules/radnerfs/*/*.py") + glob.glob("modules/radnerfs/*/*/*.py") + glob.glob("modules/radnerfs/*/*/*/*.py")
for file in all_files:
  with open(file) as f:
    lines = f.readlines()
    lines = [line.replace('-std=c++14', '-std=c++17') for line in lines]
    lines = [line.replace('\'-use_fast_math\'', '') for line in lines]
    if 'backend' in file:
      print(lines)
  with open(file, 'w') as f:
    f.writelines(lines)

# build extensions, it takes a long time (about 10 min)
# !bash docs/prepare_env/install_ext.sh
# Out:
# ['import os\n', 'from torch.utils.cpp_extension import load\n', '\n', '_src_path = os.path.dirname(os.path.abspath(__file__))\n', '\n', 'nvcc_flags = [\n', "    '-O3', '-std=c++17',\n", "    '-U__CUDA_NO_HALF_OPERATORS__', '-U__CUDA_NO_HALF_CONVERSIONS__', '-U__CUDA_NO_HALF2_OPERATORS__',\n", ']\n', '\n', 'if os.name == "posix":\n', "    c_flags = ['-O3', '-std=c++17']\n", 'elif os.name == "nt":\n', "    c_flags = ['/O2', '/std:c++17']\n", '\n', '    # find cl.exe\n', '    def find_cl_path():\n', '        import glob\n', '        for edition in ["Enterprise", "Professional", "BuildTools", "Community"]:\n', '            paths = sorted(glob.glob(r"C:\\\\Program Files (x86)\\\\Microsoft Visual Studio\\\\*\\\\%s\\\\VC\\\\Tools\\\\MSVC\\\\*\\\\bin\\\\Hostx64\\\\x64" % edition), reverse=True)\n', '            if paths:\n', '                return paths[0]\n', '\n', '    # If cl.exe is not on path, try to find it.\n', '    if os.system("where cl.exe >nul 2>nul") != 0:\n', '        cl_path = find_cl_path()\n', '        if cl_path is None:\n', '            raise RuntimeError("Could not locate a supported Microsoft Visual C++ installation")\n', '        os.environ["PATH"] += ";" + cl_path\n', '\n', "_backend = load(name='_raymarching_face',\n", '                extra_cflags=c_flags,\n', '                extra_cuda_cflags=nvcc_flags,\n', "                sources=[os.path.join(_src_path, 'src', f) for f in [\n", "                    'raymarching.cu',\n", "                    'bindings.cpp',\n", '                ]],\n', '                )\n', '\n', "__all__ = ['_backend']"]
# ['import os\n', 'from torch.utils.cpp_extension import load\n', '\n', '_src_path = os.path.dirname(os.path.abspath(__file__))\n', '\n', 'nvcc_flags = [\n', "    '-O3', '-std=c++17',\n", "    '-U__CUDA_NO_HALF_OPERATORS__', '-U__CUDA_NO_HALF_CONVERSIONS__', '-U__CUDA_NO_HALF2_OPERATORS__',\n", ']\n', '\n', 'if os.name == "posix":\n', "    c_flags = ['-O3', '-std=c++17']\n", 'elif os.name == "nt":\n', "    c_flags = ['/O2', '/std:c++17']\n", '\n', '    # find cl.exe\n', '    def find_cl_path():\n', '        import glob\n', '        for edition in ["Enterprise", "Professional", "BuildTools", "Community"]:\n', '            paths = sorted(glob.glob(r"C:\\\\Program Files (x86)\\\\Microsoft Visual Studio\\\\*\\\\%s\\\\VC\\\\Tools\\\\MSVC\\\\*\\\\bin\\\\Hostx64\\\\x64" % edition), reverse=True)\n', '            if paths:\n', '                return paths[0]\n', '\n', '    # If cl.exe is not on path, try to find it.\n', '    if os.system("where cl.exe >nul 2>nul") != 0:\n', '        cl_path = find_cl_path()\n', '        if cl_path is None:\n', '            raise RuntimeError("Could not locate a supported Microsoft Visual C++ installation")\n', '        os.environ["PATH"] += ";" + cl_path\n', '\n', "_backend = load(name='_sh_encoder',\n", '                extra_cflags=c_flags,\n', '                extra_cuda_cflags=nvcc_flags,\n', "                sources=[os.path.join(_src_path, 'src', f) for f in [\n", "                    'shencoder.cu',\n", "                    'bindings.cpp',\n", '                ]],\n', '                )\n', '\n', "__all__ = ['_backend']"]
# ['import os\n', 'from torch.utils.cpp_extension import load\n', '\n', '_src_path = os.path.dirname(os.path.abspath(__file__))\n', '\n', 'nvcc_flags = [\n', "    '-O3', '-std=c++17',\n", "    '-U__CUDA_NO_HALF_OPERATORS__', '-U__CUDA_NO_HALF_CONVERSIONS__', '-U__CUDA_NO_HALF2_OPERATORS__',\n", '    \n', ']\n', '\n', 'if os.name == "posix":\n', "    c_flags = ['-O3', '-std=c++17']\n", 'elif os.name == "nt":\n', "    c_flags = ['/O2', '/std:c++17']\n", '\n', '    # find cl.exe\n', '    def find_cl_path():\n', '        import glob\n', '        for edition in ["Enterprise", "Professional", "BuildTools", "Community"]:\n', '            paths = sorted(glob.glob(r"C:\\\\Program Files (x86)\\\\Microsoft Visual Studio\\\\*\\\\%s\\\\VC\\\\Tools\\\\MSVC\\\\*\\\\bin\\\\Hostx64\\\\x64" % edition), reverse=True)\n', '            if paths:\n', '                return paths[0]\n', '\n', '    # If cl.exe is not on path, try to find it.\n', '    if os.system("where cl.exe >nul 2>nul") != 0:\n', '        cl_path = find_cl_path()\n', '        if cl_path is None:\n', '            raise RuntimeError("Could not locate a supported Microsoft Visual C++ installation")\n', '        os.environ["PATH"] += ";" + cl_path\n', '\n', "_backend = load(name='_freqencoder',\n", '                extra_cflags=c_flags,\n', '                extra_cuda_cflags=nvcc_flags,\n', "                sources=[os.path.join(_src_path, 'src', f) for f in [\n", "                    'freqencoder.cu',\n", "                    'bindings.cpp',\n", '                ]],\n', '                )\n', '\n', "__all__ = ['_backend']"]
# ['import os\n', 'from torch.utils.cpp_extension import load\n', '\n', '_src_path = os.path.dirname(os.path.abspath(__file__))\n', '\n', 'nvcc_flags = [\n', "    '-O3', '-std=c++17',\n", "    '-U__CUDA_NO_HALF_OPERATORS__', '-U__CUDA_NO_HALF_CONVERSIONS__', '-U__CUDA_NO_HALF2_OPERATORS__',\n", ']\n', '\n', 'if os.name == "posix":\n', "    c_flags = ['-O3', '-std=c++17']\n", 'elif os.name == "nt":\n', "    c_flags = ['/O2', '/std:c++17']\n", '\n', '    # find cl.exe\n', '    def find_cl_path():\n', '        import glob\n', '        for edition in ["Enterprise", "Professional", "BuildTools", "Community"]:\n', '            paths = sorted(glob.glob(r"C:\\\\Program Files (x86)\\\\Microsoft Visual Studio\\\\*\\\\%s\\\\VC\\\\Tools\\\\MSVC\\\\*\\\\bin\\\\Hostx64\\\\x64" % edition), reverse=True)\n', '            if paths:\n', '                return paths[0]\n', '\n', '    # If cl.exe is not on path, try to find it.\n', '    if os.system("where cl.exe >nul 2>nul") != 0:\n', '        cl_path = find_cl_path()\n', '        if cl_path is None:\n', '            raise RuntimeError("Could not locate a supported Microsoft Visual C++ installation")\n', '        os.environ["PATH"] += ";" + cl_path\n', '\n', "_backend = load(name='_grid_encoder',\n", '                extra_cflags=c_flags,\n', '                extra_cuda_cflags=nvcc_flags,\n', "                sources=[os.path.join(_src_path, 'src', f) for f in [\n", "                    'gridencoder.cu',\n", "                    'bindings.cpp',\n", '                ]],\n', '                )\n', '\n', "__all__ = ['_backend']"]
# docs/prepare_env/install_ext.sh: line 2: pip: command not found
# docs/prepare_env/install_ext.sh: line 3: pip: command not found
# docs/prepare_env/install_ext.sh: line 4: pip: command not found
# docs/prepare_env/install_ext.sh: line 5: pip: command not found

# %%
# download pretrained ckpts & third-party ckpts from google drive, about 1 min

# %mkdir -p data/binary/videos/May
# %cd data/binary/videos/May
# !gdown https://drive.google.com/uc?id=16fNJz5MbOMqHYHxcK_nPP4EPBXWjugR0
# %cd ../../../..

# %cd deep_3drecon/BFM
# !gdown https://drive.google.com/uc?id=1SPM3IHsyNAaVMwqZZGV6QVaV7I2Hly0v
# !gdown https://drive.google.com/uc?id=1MSldX9UChKEb3AXLVTPzZQcsbGD4VmGF
# !gdown https://drive.google.com/uc?id=180ciTvm16peWrcpl4DOekT9eUQ-lJfMU
# !gdown https://drive.google.com/uc?id=1KX9MyGueFB3M-X0Ss152x_johyTXHTfU
# !gdown https://drive.google.com/uc?id=19-NyZn_I0_mkF-F5GPyFMwQJ_-WecZIL
# !gdown https://drive.google.com/uc?id=11ouQ7Wr2I-JKStp2Fd1afedmWeuifhof
# !gdown https://drive.google.com/uc?id=18ICIvQoKX-7feYWP61RbpppzDuYTptCq
# !gdown https://drive.google.com/uc?id=1VktuY46m0v_n_d4nvOupauJkK4LF6mHE
# %cd ../..

# %mkdir -p checkpoints
# %cd checkpoints
# !gdown https://drive.google.com/uc?id=1O5C1vK4yqguOhgRQ7kmYqa3-E8q5H_65
# !unzip motion2video_nerf.zip
# %mkdir audio2motion_vae
# %cd audio2motion_vae
# !gdown https://drive.google.com/uc?id=1Qg5V-1-IyEgAOxb2PbBjHpYkizuy6njf
# !gdown https://drive.google.com/uc?id=1bKY5rn3vcAkv-2m1mui0qr4Fs38jEmy-
# %cd ..

# %cd ..
# Out:
# /content/GeneFacePlusPlus/data/binary/videos/May
# Downloading...
# From: https://drive.google.com/uc?id=16fNJz5MbOMqHYHxcK_nPP4EPBXWjugR0
# To: /content/GeneFacePlusPlus/data/binary/videos/May/trainval_dataset.npy
# 100% 65.8M/65.8M [00:01<00:00, 63.5MB/s]
# /content/GeneFacePlusPlus
# /content/GeneFacePlusPlus/deep_3drecon/BFM
# Downloading...
# From (original): https://drive.google.com/uc?id=1SPM3IHsyNAaVMwqZZGV6QVaV7I2Hly0v
# From (redirected): https://drive.google.com/uc?id=1SPM3IHsyNAaVMwqZZGV6QVaV7I2Hly0v&confirm=t&uuid=84af1a34-a115-4d82-b643-dfd25635d707
# To: /content/GeneFacePlusPlus/deep_3drecon/BFM/01_MorphableModel.mat
# 100% 241M/241M [00:03<00:00, 72.5MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1MSldX9UChKEb3AXLVTPzZQcsbGD4VmGF
# From (redirected): https://drive.google.com/uc?id=1MSldX9UChKEb3AXLVTPzZQcsbGD4VmGF&confirm=t&uuid=c943c206-200c-4bb0-9d4d-e1f74c9e3f90
# To: /content/GeneFacePlusPlus/deep_3drecon/BFM/BFM_exp_idx.mat
# 100% 91.9k/91.9k [00:00<00:00, 82.6MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=180ciTvm16peWrcpl4DOekT9eUQ-lJfMU
# From (redirected): https://drive.google.com/uc?id=180ciTvm16peWrcpl4DOekT9eUQ-lJfMU&confirm=t&uuid=fabe8e89-e092-4d0d-be6d-663491056a82
# To: /content/GeneFacePlusPlus/deep_3drecon/BFM/BFM_front_idx.mat
# 100% 44.9k/44.9k [00:00<00:00, 85.7MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1KX9MyGueFB3M-X0Ss152x_johyTXHTfU
# From (redirected): https://drive.google.com/uc?id=1KX9MyGueFB3M-X0Ss152x_johyTXHTfU&confirm=t&uuid=674de08f-8d1d-4c45-a782-fed00e54b5eb
# To: /content/GeneFacePlusPlus/deep_3drecon/BFM/BFM_model_front.mat
# 100% 127M/127M [00:02<00:00, 55.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=19-NyZn_I0_mkF-F5GPyFMwQJ_-WecZIL
# To: /content/GeneFacePlusPlus/deep_3drecon/BFM/Exp_Pca.bin
# 100% 51.1M/51.1M [00:05<00:00, 8.62MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=11ouQ7Wr2I-JKStp2Fd1afedmWeuifhof
# From (redirected): https://drive.google.com/uc?id=11ouQ7Wr2I-JKStp2Fd1afedmWeuifhof&confirm=t&uuid=15b5d432-99dd-47b3-979e-313974da765a
# To: /content/GeneFacePlusPlus/deep_3drecon/BFM/facemodel_info.mat
# 100% 739k/739k [00:00<00:00, 144MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=18ICIvQoKX-7feYWP61RbpppzDuYTptCq
# To: /content/GeneFacePlusPlus/deep_3drecon/BFM/index_mp468_from_mesh35709.npy
# 100% 3.87k/3.87k [00:00<00:00, 20.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1VktuY46m0v_n_d4nvOupauJkK4LF6mHE
# To: /content/GeneFacePlusPlus/deep_3drecon/BFM/std_exp.txt
# 100% 615/615 [00:00<00:00, 3.05MB/s]
# /content/GeneFacePlusPlus
# /content/GeneFacePlusPlus/checkpoints
# Downloading...
# From (original): https://drive.google.com/uc?id=1O5C1vK4yqguOhgRQ7kmYqa3-E8q5H_65
# From (redirected): https://drive.google.com/uc?id=1O5C1vK4yqguOhgRQ7kmYqa3-E8q5H_65&confirm=t&uuid=e68e4466-0cd8-4062-b33a-d52ae11b9468
# To: /content/GeneFacePlusPlus/checkpoints/motion2video_nerf.zip
# 100% 66.2M/66.2M [00:02<00:00, 28.5MB/s]
# Archive:  motion2video_nerf.zip
#    creating: motion2video_nerf/
#   inflating: __MACOSX/._motion2video_nerf
#   inflating: motion2video_nerf/.DS_Store
#   inflating: __MACOSX/motion2video_nerf/._.DS_Store
#    creating: motion2video_nerf/may_head/
#    creating: motion2video_nerf/may_torso/
#   inflating: motion2video_nerf/may_head/config.yaml
#   inflating: motion2video_nerf/may_head/model_ckpt_steps_250000.ckpt
#   inflating: motion2video_nerf/may_torso/config.yaml
#   inflating: motion2video_nerf/may_torso/model_ckpt_steps_250000.ckpt
# /content/GeneFacePlusPlus/checkpoints/audio2motion_vae
# Downloading...
# From: https://drive.google.com/uc?id=1Qg5V-1-IyEgAOxb2PbBjHpYkizuy6njf
# To: /content/GeneFacePlusPlus/checkpoints/audio2motion_vae/config.yaml
# 100% 1.71k/1.71k [00:00<00:00, 6.65MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1bKY5rn3vcAkv-2m1mui0qr4Fs38jEmy-
# From (redirected): https://drive.google.com/uc?id=1bKY5rn3vcAkv-2m1mui0qr4Fs38jEmy-&confirm=t&uuid=09d49c10-8a03-4058-9db3-f2ada960380d
# To: /content/GeneFacePlusPlus/checkpoints/audio2motion_vae/model_ckpt_steps_400000.ckpt
# 100% 186M/186M [00:05<00:00, 36.9MB/s]
# /content/GeneFacePlusPlus/checkpoints
# /content/GeneFacePlusPlus

# %%
# generate training config
# !rm -rf /content/GeneFacePlusPlus/egs/datasets/georgia
# !cp -r egs/datasets/May egs/datasets/georgia

import yaml
with open("egs/datasets/georgia/lm3d_radnerf.yaml", "r+") as f:
  raw_data = f.read()
  data = yaml.safe_load(raw_data)
  data["video_id"] = "georgia"
  out_data = yaml.dump(data)
  f.seek(0)
  f.write(out_data)
  f.truncate()

# %%
# !mkdir /content/GeneFacePlusPlus/checkpoints/motion2video_nerf/georgia_head
# !cp /content/drive/MyDrive/Woodspace/model_ckpt_steps_22000.ckpt /content/GeneFacePlusPlus/checkpoints/motion2video_nerf/georgia_head/
# !cp /content/GeneFacePlusPlus/checkpoints/motion2video_nerf/georgia_head/model_ckpt_steps_22000.ckpt /content/drive/MyDrive/Woodspace/model_ckpt_steps_22000.ckpt
# !mkdir data/binary/videos/georgia
# !cp /content/drive/MyDrive/Woodspace/trainval_dataset.npy data/binary/videos/georgia/trainval_dataset.npy

# %%
# train a model on our video
# !cp /content/drive/MyDrive/Woodspace/base.mp4 data/raw/videos/georgia.mp4

import os
os.environ["PYTHONPATH"] = "."

# !CUDA_VISIBLE_DEVICES=0 bash data_gen/runs/nerf/run.sh georgia

# dataset is in data/binary/videos/georgia

# Train the Head NeRF
# model and tensorboard will be saved at `checkpoints/<exp_name>`
# !CUDA_VISIBLE_DEVICES=0 python tasks/run.py --config=egs/datasets/georgia/lm3d_radnerf_sr.yaml --exp_name=motion2video_nerf/georgia_head --reset

# Train the Torso NeRF
# !CUDA_VISIBLE_DEVICES=0 python tasks/run.py --config=egs/datasets/georgia/lm3d_radnerf_torso_sr.yaml --exp_name=motion2video_nerf/georgia_torso --hparams=head_model_dir=checkpoints/motion2video_nerf/georgia_head --reset
# Out:
# Processing georgia
# Resizing the video to 512x512
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'data/raw/videos/georgia.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:01:49.00, start: 0.000000, bitrate: 3117 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuvj420p(pc, bt709), 1080x1080, 2981 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : Core Media Video
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 libx264
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [swscaler @ 0x59c2e2414480] deprecated pixel format used, make sure you did set range correctly
# [libx264 @ 0x59c2e20252c0] -qscale is ignored, -crf is recommended.
# [libx264 @ 0x59c2e20252c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x59c2e20252c0] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x59c2e20252c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=1 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'data/raw/videos/georgia_512.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuvj420p(pc, bt709, progressive), 512x512, q=2-31, 25 fps, 12800 tbn (default)
#     Metadata:
#       handler_name    : Core Media Video
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : Core Media Audio
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 aac
# frame= 2725 fps= 37 q=-1.0 Lsize=   10410kB time=00:01:48.92 bitrate= 782.9kbits/s speed=1.49x
# video:8599kB audio:1721kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.876475%
# [libx264 @ 0x59c2e20252c0] frame I:17    Avg QP:19.50  size: 35624
# [libx264 @ 0x59c2e20252c0] frame P:725   Avg QP:22.93  size:  7316
# [libx264 @ 0x59c2e20252c0] frame B:1983  Avg QP:28.14  size:  1460
# [libx264 @ 0x59c2e20252c0] consecutive B-frames:  1.8%  2.5%  3.1% 92.6%
# [libx264 @ 0x59c2e20252c0] mb I  I16..4:  6.3% 62.9% 30.8%
# [libx264 @ 0x59c2e20252c0] mb P  I16..4:  1.2%  7.5%  2.8%  P16..4: 27.6% 16.3%  8.7%  0.0%  0.0%    skip:36.0%
# [libx264 @ 0x59c2e20252c0] mb B  I16..4:  0.1%  0.9%  0.2%  B16..8: 30.4%  6.2%  1.4%  direct: 1.4%  skip:59.4%  L0:37.6% L1:49.6% BI:12.8%
# [libx264 @ 0x59c2e20252c0] 8x8 transform intra:67.1% inter:71.6%
# [libx264 @ 0x59c2e20252c0] coded y,uvDC,uvAC intra: 73.3% 60.2% 18.8% inter: 12.6% 6.7% 0.1%
# [libx264 @ 0x59c2e20252c0] i16 v,h,dc,p: 13% 37%  6% 44%
# [libx264 @ 0x59c2e20252c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18% 13% 10%  4% 13% 17% 10% 10%  5%
# [libx264 @ 0x59c2e20252c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18% 10%  8%  4% 18% 22%  9%  9%  3%
# [libx264 @ 0x59c2e20252c0] i8c dc,h,v,p: 53% 17% 22%  8%
# [libx264 @ 0x59c2e20252c0] Weighted P-Frames: Y:1.5% UV:0.1%
# [libx264 @ 0x59c2e20252c0] ref P L0: 60.3% 18.1% 15.4%  6.1%  0.1%
# [libx264 @ 0x59c2e20252c0] ref B L0: 92.7%  5.9%  1.5%
# [libx264 @ 0x59c2e20252c0] ref B L1: 95.9%  4.1%
# [libx264 @ 0x59c2e20252c0] kb/s:646.22
# [aac @ 0x59c2e205cc00] Qavg: 384.966
# Done
# The old video is moved to data/raw/videos/georgia.mp4 data/raw/videos/georgia_to_rm.mp4
# mkdir -p data/processed/videos/georgia
# Done
# ffmpeg -i data/raw/videos/georgia.mp4 -f wav -ar 16000 -v quiet -y data/processed/videos/georgia/aud.wav
# Done
# python data_gen/utils/process_audio/extract_hubert.py --video_id=georgia
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:311: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# 2024-04-13 17:23:57.505555: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-13 17:23:57.505605: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-13 17:23:57.507005: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-13 17:23:58.630734: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:311: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# Loading the HuBERT Model...
# config.json: 100% 1.38k/1.38k [00:00<00:00, 4.59MB/s]
# pytorch_model.bin: 100% 1.26G/1.26G [00:04<00:00, 269MB/s]
# Some weights of HubertModel were not initialized from the model checkpoint at facebook/hubert-large-ls960-ft and are newly initialized: ['hubert.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'hubert.encoder.pos_conv_embed.conv.parametrizations.weight.original1']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Loading the Wav2Vec2 Processor...
# preprocessor_config.json: 100% 212/212 [00:00<00:00, 1.11MB/s]
# tokenizer_config.json: 100% 138/138 [00:00<00:00, 715kB/s]
# vocab.json: 100% 291/291 [00:00<00:00, 1.46MB/s]
# special_tokens_map.json: 100% 85.0/85.0 [00:00<00:00, 335kB/s]
# Saved at data/processed/videos/georgia/aud_hubert.npy
# python data_gen/utils/process_audio/extract_mel_f0.py --video_id=georgia
# error: XDG_RUNTIME_DIR not set in the environment.
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# Saved at data/processed/videos/georgia/aud_mel_f0.npy
# Done
# mkdir -p data/processed/videos/georgia/gt_imgs
# ffmpeg -i data/raw/videos/georgia.mp4 -vf fps=25,scale=w=512:h=512 -qmin 1 -q:v 1 -start_number 0 -v quiet data/processed/videos/georgia/gt_imgs/%08d.jpg
# Done
# python data_gen/utils/process_video/extract_segment_imgs.py --ds_name=nerf --vid_dir=data/raw/videos/georgia.mp4
# 2024-04-13 17:24:37.624206: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-13 17:24:37.624263: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-13 17:24:37.625724: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-13 17:24:37.633349: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-13 17:24:38.756404: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# todo videos number: 1
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# | Extracting Segmaps && Saving...
# generating segment images in multi-processes...:   0% 0/2725 [00:00<?, ?it/s]/usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# generating segment images in multi-processes...: 100% 2725/2725 [16:32<00:00,  2.75it/s]
# | Extracted Segmaps Done.
# | Extracting background...
# combining backgrounds...: 100% 137/137 [01:45<00:00,  1.29it/s]
# | Extracted background done.
# | Extracting com_imgs...
# extracting com_imgs: 100% 2725/2725 [01:18<00:00, 34.64it/s]
# | Extracted com_imgs done.
# Done
# python data_gen/utils/process_video/extract_lm2d.py --ds_name=nerf --vid_dir=data/raw/videos/georgia.mp4
# 2024-04-13 17:44:21.632559: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-13 17:44:21.632618: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-13 17:44:21.634027: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-13 17:44:21.641920: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-13 17:44:22.818702: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# todo videos number: 1
# Root 0: extracing MP-based landmark2d:   0% 0/1 [00:00<?, ?it/s]WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1713030271.908911   12656 face_landmarker_graph.cc:169] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1713030271.993917   12656 face_landmarker_graph.cc:169] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# Warning: failed detect ldm in idx=319, use previous frame results.
# Warning: failed detect ldm in idx=320, use previous frame results.
# Warning: failed detect ldm in idx=1545, use previous frame results.
# Warning: failed detect ldm in idx=2563, use previous frame results.
# finished 1 / 1 = 1.0000, failed 0 / 1 = 0.0000
# Root 0: extracing MP-based landmark2d: 100% 1/1 [02:01<00:00, 121.56s/it]
# Done
# python data_gen/utils/process_video/fit_3dmm_landmark.py --ds_name=nerf --vid_dir=data/raw/videos/georgia.mp4 --reset --debug --id_mode=global
# 2024-04-13 17:46:29.616005: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-13 17:46:29.616072: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-13 17:46:29.617708: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-13 17:46:29.625355: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-13 17:46:30.762518: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# args Namespace(vid_dir='data/raw/videos/georgia.mp4', ds_name='nerf', seed=0, process_id=0, total_process=1, id_mode='global', keypoint_mode='mediapipe', large_yaw_threshold=9999999.9, debug=True, reset=True, load_names=False)
# ['data/raw/videos/georgia.mp4']
# process 0: fitting 3dmm ...:   0% 0/1 [00:00<?, ?it/s]batch 0 | loss_lan: 4.32, loss_reg_id: 19.64,loss_reg_exp: 1.06,loss_lap_ldm:0.0041
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0696, loss_vel_euler: 0.0042, loss_vel_trans: 0.0233
# batch 1 | loss_lan: 4.51, loss_reg_id: 19.64,loss_reg_exp: 0.98,loss_lap_ldm:0.0079
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0889, loss_vel_euler: 0.0074, loss_vel_trans: 0.0344
# batch 2 | loss_lan: 5.08, loss_reg_id: 19.64,loss_reg_exp: 1.02,loss_lap_ldm:0.0056
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0801, loss_vel_euler: 0.0067, loss_vel_trans: 0.0317
# batch 3 | loss_lan: 6.29, loss_reg_id: 19.64,loss_reg_exp: 1.15,loss_lap_ldm:0.0035
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0785, loss_vel_euler: 0.0051, loss_vel_trans: 0.0248
# batch 4 | loss_lan: 4.60, loss_reg_id: 19.64,loss_reg_exp: 0.89,loss_lap_ldm:0.0069
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0746, loss_vel_euler: 0.0054, loss_vel_trans: 0.0248
# batch 5 | loss_lan: 4.40, loss_reg_id: 19.64,loss_reg_exp: 0.86,loss_lap_ldm:0.0040
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0733, loss_vel_euler: 0.0053, loss_vel_trans: 0.0281
# batch 6 | loss_lan: 6.30, loss_reg_id: 19.64,loss_reg_exp: 1.51,loss_lap_ldm:0.0194
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.1119, loss_vel_euler: 0.0112, loss_vel_trans: 0.0449
# batch 7 | loss_lan: 4.88, loss_reg_id: 19.64,loss_reg_exp: 1.07,loss_lap_ldm:0.0053
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0707, loss_vel_euler: 0.0054, loss_vel_trans: 0.0318
# batch 8 | loss_lan: 4.90, loss_reg_id: 19.64,loss_reg_exp: 1.07,loss_lap_ldm:0.0038
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0718, loss_vel_euler: 0.0039, loss_vel_trans: 0.0321
# batch 9 | loss_lan: 4.77, loss_reg_id: 19.64,loss_reg_exp: 1.01,loss_lap_ldm:0.0052
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0772, loss_vel_euler: 0.0043, loss_vel_trans: 0.0295
# batch 10 | loss_lan: 4.57, loss_reg_id: 19.64,loss_reg_exp: 0.95,loss_lap_ldm:0.0050
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0759, loss_vel_euler: 0.0050, loss_vel_trans: 0.0292
# batch 11 | loss_lan: 5.05, loss_reg_id: 19.64,loss_reg_exp: 1.34,loss_lap_ldm:0.0020
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0526, loss_vel_euler: 0.0036, loss_vel_trans: 0.0162
# batch 12 | loss_lan: 4.47, loss_reg_id: 19.64,loss_reg_exp: 0.93,loss_lap_ldm:0.0057
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0772, loss_vel_euler: 0.0062, loss_vel_trans: 0.0285
# batch 13 | loss_lan: 4.77, loss_reg_id: 19.64,loss_reg_exp: 1.01,loss_lap_ldm:0.0072
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0827, loss_vel_euler: 0.0064, loss_vel_trans: 0.0310
# batch 14 | loss_lan: 4.43, loss_reg_id: 19.64,loss_reg_exp: 0.85,loss_lap_ldm:0.0039
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0691, loss_vel_euler: 0.0055, loss_vel_trans: 0.0270
# batch 15 | loss_lan: 4.35, loss_reg_id: 19.64,loss_reg_exp: 0.91,loss_lap_ldm:0.0062
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0744, loss_vel_euler: 0.0044, loss_vel_trans: 0.0265
# batch 16 | loss_lan: 4.50, loss_reg_id: 19.64,loss_reg_exp: 1.03,loss_lap_ldm:0.0056
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0802, loss_vel_euler: 0.0052, loss_vel_trans: 0.0363
# batch 17 | loss_lan: 5.25, loss_reg_id: 19.64,loss_reg_exp: 1.17,loss_lap_ldm:0.0055
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0713, loss_vel_euler: 0.0054, loss_vel_trans: 0.0242
# batch 18 | loss_lan: 4.39, loss_reg_id: 19.64,loss_reg_exp: 0.93,loss_lap_ldm:0.0081
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0804, loss_vel_euler: 0.0051, loss_vel_trans: 0.0230
# batch 19 | loss_lan: 4.38, loss_reg_id: 19.64,loss_reg_exp: 0.98,loss_lap_ldm:0.0035
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0563, loss_vel_euler: 0.0033, loss_vel_trans: 0.0234
# batch 20 | loss_lan: 4.43, loss_reg_id: 19.64,loss_reg_exp: 0.80,loss_lap_ldm:0.0036
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0617, loss_vel_euler: 0.0050, loss_vel_trans: 0.0256
# batch 21 | loss_lan: 4.57, loss_reg_id: 19.64,loss_reg_exp: 0.94,loss_lap_ldm:0.0081
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0882, loss_vel_euler: 0.0063, loss_vel_trans: 0.0328
# batch 22 | loss_lan: 5.85, loss_reg_id: 19.64,loss_reg_exp: 1.02,loss_lap_ldm:0.0054
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0863, loss_vel_euler: 0.0066, loss_vel_trans: 0.0295
# batch 23 | loss_lan: 5.19, loss_reg_id: 19.64,loss_reg_exp: 1.03,loss_lap_ldm:0.0024
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0651, loss_vel_euler: 0.0061, loss_vel_trans: 0.0248
# batch 24 | loss_lan: 5.29, loss_reg_id: 19.64,loss_reg_exp: 1.02,loss_lap_ldm:0.0036
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0726, loss_vel_euler: 0.0045, loss_vel_trans: 0.0315
# batch 25 | loss_lan: 4.51, loss_reg_id: 19.64,loss_reg_exp: 0.95,loss_lap_ldm:0.0054
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0880, loss_vel_euler: 0.0072, loss_vel_trans: 0.0260
# batch 26 | loss_lan: 5.32, loss_reg_id: 19.64,loss_reg_exp: 0.98,loss_lap_ldm:0.0023
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0532, loss_vel_euler: 0.0054, loss_vel_trans: 0.0235
# batch 27 | loss_lan: 4.62, loss_reg_id: 19.64,loss_reg_exp: 1.01,loss_lap_ldm:0.0058
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0766, loss_vel_euler: 0.0072, loss_vel_trans: 0.0294
# batch 28 | loss_lan: 8.52, loss_reg_id: 19.64,loss_reg_exp: 1.86,loss_lap_ldm:0.0054
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0992, loss_vel_euler: 0.0055, loss_vel_trans: 0.0345
# batch 29 | loss_lan: 5.05, loss_reg_id: 19.64,loss_reg_exp: 1.03,loss_lap_ldm:0.0093
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0875, loss_vel_euler: 0.0093, loss_vel_trans: 0.0349
# batch 30 | loss_lan: 12.43, loss_reg_id: 19.64,loss_reg_exp: 1.62,loss_lap_ldm:0.5756
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.2265, loss_vel_euler: 0.0261, loss_vel_trans: 0.1081
# batch 31 | loss_lan: 3.15, loss_reg_id: 19.64,loss_reg_exp: 1.08,loss_lap_ldm:0.0008
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0329, loss_vel_euler: 0.0029, loss_vel_trans: 0.0085
# batch 32 | loss_lan: 3.38, loss_reg_id: 19.64,loss_reg_exp: 1.24,loss_lap_ldm:0.0064
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0553, loss_vel_euler: 0.0079, loss_vel_trans: 0.0133
# batch 33 | loss_lan: 3.05, loss_reg_id: 19.64,loss_reg_exp: 1.05,loss_lap_ldm:0.0017
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0441, loss_vel_euler: 0.0032, loss_vel_trans: 0.0078
# batch 34 | loss_lan: 4.19, loss_reg_id: 19.64,loss_reg_exp: 1.26,loss_lap_ldm:0.0028
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0419, loss_vel_euler: 0.0043, loss_vel_trans: 0.0155
# batch 35 | loss_lan: 54.97, loss_reg_id: 19.64,loss_reg_exp: 8.75,loss_lap_ldm:1.2807
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.5543, loss_vel_euler: 0.0636, loss_vel_trans: 0.2774
# batch 36 | loss_lan: 138.58, loss_reg_id: 19.64,loss_reg_exp: 22.00,loss_lap_ldm:2.5589
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.9866, loss_vel_euler: 0.1139, loss_vel_trans: 0.5213
# batch 37 | loss_lan: 25.22, loss_reg_id: 19.64,loss_reg_exp: 3.94,loss_lap_ldm:1.4649
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.4762, loss_vel_euler: 0.0584, loss_vel_trans: 0.2690
# batch 38 | loss_lan: 96.70, loss_reg_id: 19.64,loss_reg_exp: 14.66,loss_lap_ldm:2.7274
# |--------loss_vel_id: 0.0000, loss_vel_exp: 1.0198, loss_vel_euler: 0.1181, loss_vel_trans: 0.5309
# batch 39 | loss_lan: 3.17, loss_reg_id: 19.64,loss_reg_exp: 1.14,loss_lap_ldm:0.0015
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0363, loss_vel_euler: 0.0029, loss_vel_trans: 0.0072
# batch 40 | loss_lan: 3.52, loss_reg_id: 19.64,loss_reg_exp: 1.15,loss_lap_ldm:0.0016
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0433, loss_vel_euler: 0.0041, loss_vel_trans: 0.0108
# batch 41 | loss_lan: 3.04, loss_reg_id: 19.64,loss_reg_exp: 0.96,loss_lap_ldm:0.0024
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0563, loss_vel_euler: 0.0053, loss_vel_trans: 0.0113
# batch 42 | loss_lan: 14.47, loss_reg_id: 19.64,loss_reg_exp: 2.15,loss_lap_ldm:0.7472
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.2546, loss_vel_euler: 0.0374, loss_vel_trans: 0.1546
# batch 43 | loss_lan: 3.45, loss_reg_id: 19.64,loss_reg_exp: 1.09,loss_lap_ldm:0.0016
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0441, loss_vel_euler: 0.0064, loss_vel_trans: 0.0167
# batch 44 | loss_lan: 2.97, loss_reg_id: 19.64,loss_reg_exp: 0.96,loss_lap_ldm:0.0038
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0565, loss_vel_euler: 0.0065, loss_vel_trans: 0.0158
# batch 45 | loss_lan: 19.90, loss_reg_id: 19.64,loss_reg_exp: 3.38,loss_lap_ldm:0.5552
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.3132, loss_vel_euler: 0.0382, loss_vel_trans: 0.1415
# batch 46 | loss_lan: 3.67, loss_reg_id: 19.64,loss_reg_exp: 1.31,loss_lap_ldm:0.0021
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0402, loss_vel_euler: 0.0055, loss_vel_trans: 0.0161
# batch 47 | loss_lan: 4.61, loss_reg_id: 19.64,loss_reg_exp: 1.74,loss_lap_ldm:0.0016
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0503, loss_vel_euler: 0.0062, loss_vel_trans: 0.0175
# batch 48 | loss_lan: 3.49, loss_reg_id: 19.64,loss_reg_exp: 1.34,loss_lap_ldm:0.0018
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0365, loss_vel_euler: 0.0049, loss_vel_trans: 0.0118
# batch 49 | loss_lan: 37.07, loss_reg_id: 19.64,loss_reg_exp: 4.29,loss_lap_ldm:1.3997
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.3548, loss_vel_euler: 0.0296, loss_vel_trans: 0.1789
# batch 50 | loss_lan: 33.02, loss_reg_id: 19.64,loss_reg_exp: 4.28,loss_lap_ldm:1.3651
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.3821, loss_vel_euler: 0.0382, loss_vel_trans: 0.1815
# batch 51 | loss_lan: 172.51, loss_reg_id: 19.64,loss_reg_exp: 30.40,loss_lap_ldm:0.2276
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.2506, loss_vel_euler: 0.0282, loss_vel_trans: 0.0849
# batch 52 | loss_lan: 109.11, loss_reg_id: 19.64,loss_reg_exp: 18.18,loss_lap_ldm:1.0404
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.3846, loss_vel_euler: 0.0587, loss_vel_trans: 0.2418
# batch 53 | loss_lan: 360.14, loss_reg_id: 19.64,loss_reg_exp: 58.55,loss_lap_ldm:0.0032
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0831, loss_vel_euler: 0.0041, loss_vel_trans: 0.0314
# batch 54 | loss_lan: 380.27, loss_reg_id: 19.64,loss_reg_exp: 60.67,loss_lap_ldm:0.0020
# |--------loss_vel_id: 0.0000, loss_vel_exp: 0.0675, loss_vel_euler: 0.0026, loss_vel_trans: 0.0206
#
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:   0% 0/250 [00:00<?, ?it/s]create rasterizer on device cuda:0
# /usr/lib/python3.10/subprocess.py:1796: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _posixsubprocess.fork_exec(
#
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:   0% 1/250 [00:01<04:48,  1.16s/it]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:   1% 2/250 [00:01<02:51,  1.45it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:   1% 3/250 [00:01<02:08,  1.92it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:   2% 4/250 [00:02<01:48,  2.28it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:   2% 5/250 [00:02<01:37,  2.52it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:   2% 6/250 [00:02<01:42,  2.37it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:   3% 7/250 [00:03<01:33,  2.61it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:   3% 8/250 [00:03<01:27,  2.77it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:   4% 9/250 [00:04<01:50,  2.19it/s]/content/GeneFacePlusPlus/utils/visualization/vis_cam3d/camera_pose_visualizer.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   self.fig = plt.figure(figsize=(5.12, 5.12))
#
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:   4% 10/250 [00:04<01:39,  2.42it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:   4% 11/250 [00:04<01:30,  2.63it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:   5% 12/250 [00:05<01:25,  2.79it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:   5% 13/250 [00:05<01:22,  2.87it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:   6% 14/250 [00:05<01:20,  2.93it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:   6% 15/250 [00:06<01:20,  2.90it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:   6% 16/250 [00:06<01:29,  2.60it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:   7% 17/250 [00:07<01:35,  2.45it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:   7% 18/250 [00:07<01:40,  2.31it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:   8% 19/250 [00:08<01:42,  2.26it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:   8% 20/250 [00:08<01:45,  2.19it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:   8% 21/250 [00:09<01:46,  2.15it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:   9% 22/250 [00:09<01:47,  2.12it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:   9% 23/250 [00:09<01:45,  2.14it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  10% 24/250 [00:10<01:46,  2.12it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  10% 25/250 [00:10<01:44,  2.15it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  10% 26/250 [00:11<01:45,  2.12it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  11% 27/250 [00:11<01:39,  2.25it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  11% 28/250 [00:12<01:29,  2.48it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  12% 29/250 [00:12<01:22,  2.69it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  12% 30/250 [00:13<01:43,  2.12it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  12% 31/250 [00:13<01:32,  2.36it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  13% 32/250 [00:13<01:30,  2.41it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  13% 33/250 [00:14<01:23,  2.60it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  14% 34/250 [00:14<01:17,  2.79it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  14% 35/250 [00:14<01:14,  2.90it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  14% 36/250 [00:15<01:13,  2.89it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  15% 37/250 [00:15<01:11,  2.99it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  15% 38/250 [00:15<01:09,  3.05it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  16% 39/250 [00:16<01:08,  3.07it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  16% 40/250 [00:16<01:07,  3.12it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  16% 41/250 [00:16<01:05,  3.18it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  17% 42/250 [00:16<01:05,  3.16it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  17% 43/250 [00:17<01:11,  2.88it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  18% 44/250 [00:17<01:12,  2.83it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  18% 45/250 [00:18<01:09,  2.96it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  18% 46/250 [00:18<01:08,  3.00it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  19% 47/250 [00:18<01:07,  3.00it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  19% 48/250 [00:19<01:09,  2.92it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  20% 49/250 [00:19<01:16,  2.61it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  20% 50/250 [00:19<01:14,  2.68it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  20% 51/250 [00:20<01:13,  2.70it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  21% 52/250 [00:20<01:13,  2.70it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  21% 53/250 [00:20<01:13,  2.67it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  22% 54/250 [00:21<01:13,  2.67it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  22% 55/250 [00:21<01:24,  2.31it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  22% 56/250 [00:23<02:08,  1.51it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  23% 57/250 [00:23<02:00,  1.61it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  23% 58/250 [00:24<01:52,  1.71it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  24% 59/250 [00:24<01:42,  1.87it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  24% 60/250 [00:25<01:41,  1.87it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  24% 61/250 [00:25<01:39,  1.90it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  25% 62/250 [00:26<01:42,  1.84it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  25% 63/250 [00:26<01:46,  1.76it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  26% 64/250 [00:27<01:42,  1.82it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  26% 65/250 [00:27<01:31,  2.03it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  26% 66/250 [00:28<01:21,  2.26it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  27% 67/250 [00:28<01:15,  2.43it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  27% 68/250 [00:28<01:10,  2.57it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  28% 69/250 [00:29<01:09,  2.60it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  28% 70/250 [00:29<01:07,  2.65it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  28% 71/250 [00:29<01:06,  2.67it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  29% 72/250 [00:30<01:07,  2.64it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  29% 73/250 [00:30<01:03,  2.78it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  30% 74/250 [00:30<01:04,  2.75it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  30% 75/250 [00:31<01:02,  2.79it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  30% 76/250 [00:31<01:01,  2.84it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  31% 77/250 [00:31<01:02,  2.75it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  31% 78/250 [00:32<01:02,  2.77it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  32% 79/250 [00:32<01:00,  2.83it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  32% 80/250 [00:33<01:01,  2.75it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  32% 81/250 [00:33<01:06,  2.55it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  33% 82/250 [00:33<01:02,  2.69it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  33% 83/250 [00:34<01:00,  2.78it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  34% 84/250 [00:34<01:00,  2.76it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  34% 85/250 [00:34<00:59,  2.78it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  34% 86/250 [00:35<00:57,  2.85it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  35% 87/250 [00:35<00:56,  2.87it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  35% 88/250 [00:35<00:57,  2.82it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  36% 89/250 [00:36<01:28,  1.82it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  36% 90/250 [00:37<01:19,  2.02it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  36% 91/250 [00:37<01:19,  2.01it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  37% 92/250 [00:38<01:19,  1.98it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  37% 93/250 [00:38<01:21,  1.93it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  38% 94/250 [00:39<01:16,  2.03it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  38% 95/250 [00:39<01:17,  2.01it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  38% 96/250 [00:40<01:20,  1.92it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  39% 97/250 [00:40<01:19,  1.91it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  39% 98/250 [00:41<01:19,  1.91it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  40% 99/250 [00:41<01:20,  1.87it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  40% 100/250 [00:42<01:23,  1.80it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  40% 101/250 [00:43<01:17,  1.92it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  41% 102/250 [00:43<01:08,  2.15it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  41% 103/250 [00:43<01:02,  2.35it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  42% 104/250 [00:44<01:01,  2.39it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  42% 105/250 [00:44<00:57,  2.51it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  42% 106/250 [00:44<00:54,  2.62it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  43% 107/250 [00:45<00:53,  2.69it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  43% 108/250 [00:45<00:52,  2.72it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  44% 109/250 [00:45<00:51,  2.72it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  44% 110/250 [00:46<00:50,  2.78it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  44% 111/250 [00:46<00:48,  2.85it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  45% 112/250 [00:46<00:50,  2.73it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  45% 113/250 [00:47<00:50,  2.71it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  46% 114/250 [00:47<00:50,  2.71it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  46% 115/250 [00:48<00:49,  2.71it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  46% 116/250 [00:48<00:48,  2.76it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  47% 117/250 [00:48<00:49,  2.67it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  47% 118/250 [00:49<00:52,  2.52it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  48% 119/250 [00:49<00:50,  2.62it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  48% 120/250 [00:49<00:49,  2.61it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  48% 121/250 [00:50<00:47,  2.73it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  49% 122/250 [00:50<00:46,  2.76it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  49% 123/250 [00:50<00:44,  2.85it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  50% 124/250 [00:51<00:46,  2.72it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  50% 125/250 [00:51<00:45,  2.74it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  50% 126/250 [00:52<00:44,  2.82it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  51% 127/250 [00:52<00:43,  2.85it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  51% 128/250 [00:52<00:46,  2.65it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  52% 129/250 [00:54<01:28,  1.37it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  52% 130/250 [00:54<01:19,  1.50it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  52% 131/250 [00:55<01:13,  1.62it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  53% 132/250 [00:56<01:11,  1.66it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  53% 133/250 [00:56<01:07,  1.73it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  54% 134/250 [00:57<01:06,  1.74it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  54% 135/250 [00:57<01:04,  1.79it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  54% 136/250 [00:58<01:01,  1.86it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  55% 137/250 [00:58<00:53,  2.11it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  55% 138/250 [00:58<00:47,  2.34it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  56% 139/250 [00:59<00:44,  2.50it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  56% 140/250 [00:59<00:42,  2.62it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  56% 141/250 [00:59<00:41,  2.61it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  57% 142/250 [01:00<00:40,  2.66it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  57% 143/250 [01:00<00:39,  2.74it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  58% 144/250 [01:00<00:37,  2.79it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  58% 145/250 [01:01<00:39,  2.68it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  58% 146/250 [01:01<00:37,  2.74it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  59% 147/250 [01:01<00:37,  2.74it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  59% 148/250 [01:02<00:40,  2.52it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  60% 149/250 [01:02<00:38,  2.65it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  60% 150/250 [01:03<00:37,  2.64it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  60% 151/250 [01:03<00:36,  2.73it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  61% 152/250 [01:03<00:35,  2.75it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  61% 153/250 [01:04<00:35,  2.76it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  62% 154/250 [01:04<00:35,  2.73it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  62% 155/250 [01:04<00:33,  2.82it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  62% 156/250 [01:05<00:35,  2.68it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  63% 157/250 [01:05<00:34,  2.70it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  63% 158/250 [01:06<00:32,  2.79it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  64% 159/250 [01:06<00:32,  2.79it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  64% 160/250 [01:06<00:31,  2.83it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  64% 161/250 [01:07<00:31,  2.79it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  65% 162/250 [01:07<00:31,  2.79it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  65% 163/250 [01:07<00:30,  2.86it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  66% 164/250 [01:08<00:34,  2.53it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  66% 165/250 [01:08<00:35,  2.37it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  66% 166/250 [01:09<00:38,  2.20it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  67% 167/250 [01:09<00:39,  2.11it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  67% 168/250 [01:10<00:39,  2.07it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  68% 169/250 [01:10<00:39,  2.04it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  68% 170/250 [01:11<00:41,  1.91it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  68% 171/250 [01:11<00:41,  1.93it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  69% 172/250 [01:12<00:42,  1.84it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  69% 173/250 [01:13<00:42,  1.82it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  70% 174/250 [01:13<00:40,  1.86it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  70% 175/250 [01:14<00:36,  2.04it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  70% 176/250 [01:14<00:34,  2.15it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  71% 177/250 [01:14<00:31,  2.34it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  71% 178/250 [01:15<00:28,  2.52it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  72% 179/250 [01:15<00:26,  2.68it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  72% 180/250 [01:16<00:48,  1.44it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  72% 181/250 [01:17<00:40,  1.70it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  73% 182/250 [01:17<00:34,  1.97it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  73% 183/250 [01:17<00:30,  2.19it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  74% 184/250 [01:18<00:27,  2.37it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  74% 185/250 [01:18<00:26,  2.46it/s]
# ...
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  86% 214/250 [01:31<00:14,  2.55it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  86% 215/250 [01:31<00:13,  2.67it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  86% 216/250 [01:31<00:13,  2.57it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  87% 217/250 [01:32<00:12,  2.67it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  87% 218/250 [01:32<00:12,  2.65it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  88% 219/250 [01:32<00:11,  2.72it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  88% 220/250 [01:33<00:11,  2.62it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  88% 221/250 [01:33<00:11,  2.63it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  89% 222/250 [01:34<00:10,  2.68it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  89% 223/250 [01:34<00:09,  2.70it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  90% 224/250 [01:34<00:09,  2.63it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  90% 225/250 [01:35<00:09,  2.70it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  90% 226/250 [01:35<00:08,  2.67it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  91% 227/250 [01:35<00:08,  2.68it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  91% 228/250 [01:36<00:08,  2.74it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  92% 229/250 [01:36<00:07,  2.67it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  92% 230/250 [01:37<00:07,  2.67it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  92% 231/250 [01:37<00:06,  2.78it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  93% 232/250 [01:37<00:06,  2.81it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  93% 233/250 [01:38<00:06,  2.70it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  94% 234/250 [01:38<00:05,  2.74it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  94% 235/250 [01:38<00:05,  2.78it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  94% 236/250 [01:39<00:05,  2.69it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  95% 237/250 [01:39<00:05,  2.59it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  95% 238/250 [01:40<00:05,  2.34it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  96% 239/250 [01:40<00:04,  2.27it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  96% 240/250 [01:41<00:04,  2.08it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  96% 241/250 [01:41<00:04,  2.12it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  97% 242/250 [01:43<00:08,  1.02s/it]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  97% 243/250 [01:44<00:05,  1.18it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  98% 244/250 [01:44<00:04,  1.43it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  98% 245/250 [01:45<00:02,  1.68it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  98% 246/250 [01:45<00:02,  1.93it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  99% 247/250 [01:45<00:01,  2.12it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..:  99% 248/250 [01:46<00:00,  2.30it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..: 100% 249/250 [01:46<00:00,  2.37it/s]
# rendering debug video to data/processed/videos/georgia/debug_fit_3dmm.mp4..: 100% 250/250 [01:46<00:00,  2.34it/s]
# finished 1 / 1 = 1.0000, failed 0 / 1 = 0.0000
# process 0: fitting 3dmm ...: 100% 1/1 [02:25<00:00, 145.61s/it]
# all failed image names: []
# All finished!
# Done
# python data_gen/runs/binarizer_nerf.py --video_id=georgia
# /content/GeneFacePlusPlus/data_gen/runs/binarizer_nerf.py:213: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   ret_dict['bg_img'] = imageio.imread(background_img_name)
# loading lm2d coeff ...
# loading fitted 3dmm coeff ...
# calculating lm3d ...
# loading hubert ...
# loading Mel and F0 ...
# Binarization for georgia Done!
# Done
# | set_hparams Unknow hparams:  []
# | Hparams chains:  ['egs/egs_bases/radnerf/base.yaml', 'egs/egs_bases/radnerf/lm3d_radnerf.yaml', 'egs/datasets/georgia/lm3d_radnerf.yaml', 'egs/datasets/georgia/lm3d_radnerf_sr.yaml']
# | Hparams:  {
#   "accumulate_grad_batches": 1,
#   "add_eye_blink_cond": true,
#   "ambient_coord_dim": 3,
#   "ambient_loss_mode": "mae",
#   "amp": true,
#   "base_config": [
#     "./lm3d_radnerf.yaml"
#   ],
#   "binary_data_dir": "data/binary/videos",
#   "bound": 1,
#   "camera_offset": [
#     0,
#     0,
#     0
#   ],
#   "camera_scale": 4.0,
#   "clip_grad_norm": 0.0,
#   "clip_grad_value": 0,
#   "cond_dropout_rate": 0.0,
#   "cond_out_dim": 64,
#   "cond_type": "idexp_lm3d_normalized",
#   "cond_win_size": 1,
#   "cuda_ray": true,
#   "debug": false,
#   "density_thresh": 10,
#   "density_thresh_torso": 0.01,
#   "desired_resolution": 2048,
#   "dt_gamma": 0.00390625,
#   "eval_max_batches": 100,
#   "exp_name": "motion2video_nerf/georgia_head",
#   "eye_blink_dim": 2,
#   "far": 0.9,
#   "finetune_lips": true,
#   "finetune_lips_start_iter": 200000,
#   "geo_feat_dim": 128,
#   "grid_interpolation_type": "linear",
#   "grid_size": 128,
#   "grid_type": "tiledgrid",
#   "gui_fovy": 21.24,
#   "gui_h": 512,
#   "gui_max_spp": 1,
#   "gui_radius": 3.35,
#   "gui_w": 512,
#   "hidden_dim_ambient": 128,
#   "hidden_dim_color": 128,
#   "hidden_dim_sigma": 128,
#   "individual_embedding_dim": 4,
#   "individual_embedding_num": 13000,
#   "infer": false,
#   "infer_audio_source_name": "",
#   "infer_bg_img_fname": "",
#   "infer_c2w_name": "",
#   "infer_cond_name": "",
#   "infer_lm3d_clamp_std": 1.5,
#   "infer_lm3d_lle_percent": 0.25,
#   "infer_lm3d_smooth_sigma": 0.0,
#   "infer_out_video_name": "",
#   "infer_scale_factor": 1.0,
#   "infer_smo_std": 0.0,
#   "infer_smooth_camera_path": true,
#   "infer_smooth_camera_path_kernel_size": 7,
#   "init_method": "tcp",
#   "lambda_ambient": null,
#   "lambda_dual_fm": 0.0,
#   "lambda_lap_ambient_loss": 0.0,
#   "lambda_lpips_loss": 0.001,
#   "lambda_weights_entropy": 0.0001,
#   "load_ckpt": "",
#   "load_imgs_to_memory": false,
#   "log2_hashmap_size": 16,
#   "lpips_mode": "vgg19_v2",
#   "lpips_start_iters": 200000,
#   "lr": 0.0005,
#   "lr_lambda_ambient": 0.01,
#   "max_ray_batch": 4096,
#   "max_steps": 16,
#   "max_updates": 250000,
#   "min_near": 0.05,
#   "n_rays": 65536,
#   "near": 0.3,
#   "nerf_keypoint_mode": "lm68",
#   "not_save_modules": [
#     "criterion_lpips",
#     "dual_disc"
#   ],
#   "num_ckpt_keep": 1,
#   "num_layers_ambient": 3,
#   "num_layers_color": 2,
#   "num_layers_sigma": 3,
#   "num_sanity_val_steps": 2,
#   "num_steps": 16,
#   "num_valid_plots": 5,
#   "optimizer_adam_beta1": 0.9,
#   "optimizer_adam_beta2": 0.999,
#   "polygon_face_mask": true,
#   "print_nan_grads": false,
#   "processed_data_dir": "data/processed/videos",
#   "raw_data_dir": "data/raw/videos",
#   "resume_from_checkpoint": 0,
#   "save_best": true,
#   "save_codes": [
#     "tasks",
#     "modules",
#     "egs"
#   ],
#   "save_gt": true,
#   "scheduler": "exponential",
#   "seed": 9999,
#   "smo_win_size": 3,
#   "smooth_lips": false,
#   "sr_start_iters": 0,
#   "start_rank": 0,
#   "target_ambient_loss": 1e-08,
#   "task_cls": "tasks.radnerfs.radnerf_sr.RADNeRFTask",
#   "tb_log_interval": 100,
#   "torso_head_aware": false,
#   "torso_individual_embedding_dim": 8,
#   "torso_shrink": 0.8,
#   "update_extra_interval": 16,
#   "upsample_steps": 0,
#   "use_window_cond": true,
#   "val_check_interval": 2000,
#   "valid_infer_interval": 10000,
#   "valid_monitor_key": "val_loss",
#   "valid_monitor_mode": "min",
#   "validate": false,
#   "video_id": "georgia",
#   "warmup_updates": 0,
#   "weight_decay": 0,
#   "with_att": true,
#   "with_sr": true,
#   "work_dir": "checkpoints/motion2video_nerf/georgia_head",
#   "world_size": -1,
#   "zero_dummy": true
# }
# 2024-04-13 17:49:15.374797: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-13 17:49:15.374858: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-13 17:49:15.376327: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-13 17:49:16.483034: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 04/13 05:49:17 PM GPU available: True, GPU used: [0], world_size: 1, multi-machine training: False
# /content/GeneFacePlusPlus/tasks/radnerfs/dataset_utils.py:266: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.lm68s = torch.tensor(self.lm2ds[:, index_lm68_from_lm478, :])
# val: Smooth head trajectory (rotation and translation) with a window size of 7
# | Copied codes to checkpoints/motion2video_nerf/georgia_head/codes/20240413174931.
# | cond_prenet Trainable Parameters: 0.050M
# | blink_embedding Trainable Parameters: 0.000M
# | blink_encoder Trainable Parameters: 0.001M
# | cond_att_net Trainable Parameters: 0.004M
# | position_embedder Trainable Parameters: 1.807M
# | ambient_net Trainable Parameters: 0.029M
# | ambient_embedder Trainable Parameters: 1.807M
# | sigma_net Trainable Parameters: 0.041M
# | direction_embedder Trainable Parameters: 0.000M
# | color_net Trainable Parameters: 0.019M
# | dropout Trainable Parameters: 0.000M
# | sr_net Trainable Parameters: 0.271M
# Sanity Val:   0% 0/2 [00:00<?, ?step/s]/content/GeneFacePlusPlus/tasks/radnerfs/dataset_utils.py:427: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   sample['lm68'] = torch.tensor(self.lm68s[idx].reshape([68*2]))
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Sanity Val:  50% 1/2 [01:28<01:28, 88.38s/step]/content/GeneFacePlusPlus/tasks/radnerfs/dataset_utils.py:427: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   sample['lm68'] = torch.tensor(self.lm68s[idx].reshape([68*2]))
# Sanity Val: 100% 2/2 [01:28<00:00, 44.27s/step]
# | Validation results@22000: {'total_loss': 9.4093470573, 'mse_loss': 0.0704146549, 'sr_mse_loss': 0.0718766935, 'lambda_ambient': 9.2670555115}
# 24000step [06:38,  5.78step/s, ambient_loss=4.21e-5, density_grid_info_max_density=2.87e+3, density_grid_info_mean_density=4.2, density_grid_info_min_density=-1, density_grid_info_occupancy_rate=0.264, density_grid_info_step_mean_count=387923, head_psnr=14.6, lambda_ambient=10.6, lr_optimizer0_params_group0=0.000401, lr_optimizer0_params_group1=0.00401, lr_optimizer0_params_group2=0.002, mse_loss=0.0348, num_non_facemask=57042, sr_mse_loss=0.0231, weights_entropy_loss=0.292]
# Valid:   0% 0/100 [00:00<?, ?step/s]
# Valid:   2% 2/100 [00:00<00:06, 15.06step/s]
# Valid:   4% 4/100 [00:00<00:07, 12.23step/s]
# Valid:   6% 6/100 [00:00<00:08, 11.40step/s]
# Valid:   8% 8/100 [00:00<00:08, 10.63step/s]
# Valid:  10% 10/100 [00:00<00:09,  9.86step/s]
# Valid:  12% 12/100 [00:01<00:08,  9.95step/s]
# Valid:  14% 14/100 [00:01<00:07, 11.42step/s]
# Valid:  16% 16/100 [00:01<00:06, 12.19step/s]
# Valid:  18% 18/100 [00:01<00:06, 12.18step/s]
# Valid:  20% 20/100 [00:01<00:06, 11.90step/s]
# Valid:  22% 22/100 [00:01<00:07, 10.65step/s]
# Valid:  24% 24/100 [00:02<00:06, 10.92step/s]
# Valid:  26% 26/100 [00:02<00:07, 10.20step/s]
# Valid:  28% 28/100 [00:02<00:07,  9.59step/s]
# Valid:  29% 29/100 [00:02<00:07,  9.40step/s]
# Valid:  31% 31/100 [00:02<00:06,  9.92step/s]
# Valid:  32% 32/100 [00:03<00:06,  9.81step/s]
# Valid:  34% 34/100 [00:03<00:06, 10.11step/s]
# Valid:  36% 36/100 [00:03<00:05, 11.00step/s]
# Valid:  38% 38/100 [00:03<00:05, 11.22step/s]
# Valid:  40% 40/100 [00:03<00:05, 11.12step/s]
# Valid:  42% 42/100 [00:03<00:05, 10.89step/s]
# Valid:  44% 44/100 [00:04<00:05, 11.17step/s]
# Valid:  46% 46/100 [00:04<00:05, 10.64step/s]
# Valid:  48% 48/100 [00:04<00:05,  9.68step/s]
# Valid:  49% 49/100 [00:04<00:05,  9.26step/s]
# Valid:  51% 51/100 [00:04<00:04,  9.83step/s]
# Valid:  53% 53/100 [00:05<00:04,  9.56step/s]
# Valid:  54% 54/100 [00:05<00:04,  9.23step/s]
# Valid:  55% 55/100 [00:05<00:05,  8.93step/s]
# Valid:  57% 57/100 [00:05<00:04,  9.39step/s]
# Valid:  58% 58/100 [00:05<00:04,  9.12step/s]
# Valid:  59% 59/100 [00:05<00:04,  8.73step/s]
# Valid:  61% 61/100 [00:05<00:04,  9.52step/s]
# Valid:  63% 63/100 [00:06<00:03,  9.38step/s]
# Valid:  65% 65/100 [00:06<00:03,  9.82step/s]
# Valid:  67% 67/100 [00:06<00:03,  9.58step/s]
# Valid:  69% 69/100 [00:06<00:03,  9.41step/s]
# Valid:  70% 70/100 [00:06<00:03,  8.96step/s]
# Valid:  71% 71/100 [00:07<00:03,  9.06step/s]
# Valid:  72% 72/100 [00:07<00:03,  9.15step/s]
# Valid:  74% 74/100 [00:07<00:02,  9.17step/s]
# Valid:  76% 76/100 [00:07<00:02, 10.29step/s]
# Valid:  78% 78/100 [00:07<00:02, 10.11step/s]
# Valid:  80% 80/100 [00:07<00:01, 10.97step/s]
# Valid:  82% 82/100 [00:07<00:01, 11.68step/s]
# Valid:  84% 84/100 [00:08<00:01, 12.47step/s]
# Valid:  86% 86/100 [00:08<00:01, 12.23step/s]
# Valid:  88% 88/100 [00:08<00:01, 11.12step/s]
# Valid:  90% 90/100 [00:08<00:00, 10.95step/s]
# Valid:  92% 92/100 [00:08<00:00, 10.69step/s]
# Valid:  94% 94/100 [00:09<00:00, 11.40step/s]
# Valid:  96% 96/100 [00:09<00:00, 10.38step/s]
# Valid:  98% 98/100 [00:09<00:00, 10.10step/s]
# Valid: 100% 100/100 [00:09<00:00, 10.38step/s]
# | Validation results@24000: {'total_loss': 10.6536788273, 'mse_loss': 0.0443900945, 'sr_mse_loss': 0.0471539461, 'lambda_ambient': 10.5621347427}
# 04/13 05:57:55 PM Epoch 00000@24000: saving model to checkpoints/motion2video_nerf/georgia_head/model_ckpt_steps_24000.ckpt
# 04/13 05:57:55 PM Delete ckpt: model_ckpt_steps_22000.ckpt
# 24470step [08:19,  4.94step/s, ambient_loss=3.26e-5, head_psnr=15.7, lambda_ambient=10.6, lr_optimizer0_params_group0=0.000399, lr_optimizer0_params_group1=0.00399, lr_optimizer0_params_group2=0.002, mse_loss=0.0269, num_non_facemask=56365, sr_mse_loss=0.0168, weights_entropy_loss=0.302]
# Valid: 100% 100/100 [00:09<00:00, 10.04step/s]
# | Validation results@26000: {'total_loss': 11.3971470642, 'mse_loss': 0.0480781446, 'sr_mse_loss': 0.0518782651, 'lambda_ambient': 11.2971906662}
# 04/13 06:04:37 PM Epoch 00000@26000: saving model to checkpoints/motion2video_nerf/georgia_head/model_ckpt_steps_26000.ckpt
# 04/13 06:04:37 PM Delete ckpt: model_ckpt_steps_24000.ckpt
# Valid: 100% 100/100 [00:09<00:00, 10.53step/s]
# | Validation results@28000: {'total_loss': 16.1316206169, 'mse_loss': 0.0465635555, 'sr_mse_loss': 0.0479743235, 'lambda_ambient': 16.0370826721}
# 04/13 06:11:17 PM Epoch 00000@28000: saving model to checkpoints/motion2video_nerf/georgia_head/model_ckpt_steps_28000.ckpt
# 04/13 06:11:17 PM Delete ckpt: model_ckpt_steps_26000.ckpt

# %% [markdown]
# Inference sample

# %%
# sample inference, about 3 min
# !python inference/genefacepp_infer.py \
--a2m_ckpt=checkpoints/audio2motion_vae \
--head_ckpt=checkpoints/motion2video_nerf/georgia_head/model_ckpt_steps_22000.ckpt \
--torso_ckpt= \
--drv_aud=/content/drive/MyDrive/Woodspace/1A.mp3 \
--out_name=1A.mp4 \
--low_memory_usage

# %% [markdown]
# Display output video

# %%
# borrow code from makeittalk
from IPython.display import HTML
from base64 import b64encode
import os, sys
import glob

mp4_name = './may_demo.mp4'

mp4 = open('{}'.format(mp4_name),'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

print('Display animation: {}'.format(mp4_name), file=sys.stderr)
display(HTML("""
  <video width=256 controls>
        <source src="%s" type="video/mp4">
  </video>
  """ % data_url))
